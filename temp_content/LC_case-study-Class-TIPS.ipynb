# %% [markdown]
# *Find patterns for DEFAULTED people*

# %% [markdown]
# Do lot of Univariate and Bivariate analysis

# %% [markdown]
# Bucket your data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Group by year how many defaulters per year

# %% [markdown]
# Buckcet interest-rates and number of defaulters in these buckets

# %% [markdown]
# Find the simple columns which are useful and make note of them; then derive from the further analysis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.youtube.com/user/khanacademy ===> best for statistics topics
